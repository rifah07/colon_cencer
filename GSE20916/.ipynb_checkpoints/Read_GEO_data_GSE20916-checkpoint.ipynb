# %%
import pandas as pd
import re

# %%
#file path
file_path = "GSE20916_series_matrix.txt"

# Read the file, ignoring comment lines and extracting metadata
metadata = {}
with open(file_path, "r") as file:
    for line in file:
        if line.startswith("!Sample_"):
            key, values = line.split("\t", 1)
            key = key.replace("!Sample_", "").strip()
            values = values.strip().split("\t")
            metadata[key] = values

df_metadata_all = pd.DataFrame(metadata)

# Identify and rename relevant metadata fields if needed
#relevant_columns = ["age", "sex", "disease state", "treatment", "other metadata fields"]
#for col in df_metadata_all.columns:
#    if any(keyword in col.lower() for keyword in relevant_columns):
 #       df_metadata.rename(columns={col: col.lower().replace(" ", "_")}, inplace=True)

# Display the first few rows of the metadata
print(df_metadata_all.head())
# Out:
#        title geo_accession                   status submission_date  \
# 0  "10167 N"  "GSM1092909"  "Public on Feb 19 2014"   "Mar 05 2013"
# 1  "10167 T"  "GSM1092910"  "Public on Feb 19 2014"   "Mar 05 2013"
# 2  "10212 N"  "GSM1092911"  "Public on Feb 19 2014"   "Mar 05 2013"
# 3  "10212 T"  "GSM1092912"  "Public on Feb 19 2014"   "Mar 05 2013"
# 4  "10515 N"  "GSM1092913"  "Public on Feb 19 2014"   "Mar 05 2013"
#
#   last_update_date   type channel_count  \
# 0    "Jun 02 2014"  "RNA"           "1"
# 1    "Jun 02 2014"  "RNA"           "1"
# 2    "Jun 02 2014"  "RNA"           "1"
# 3    "Jun 02 2014"  "RNA"           "1"
# 4    "Jun 02 2014"  "RNA"           "1"
#
#                                  source_name_ch1    organism_ch1  \
# 0  "Colon tissue from patient with colon cancer"  "Homo sapiens"
# 1  "Colon tissue from patient with colon cancer"  "Homo sapiens"
# 2  "Colon tissue from patient with colon cancer"  "Homo sapiens"
# ...

# %%
# Save the metadata DataFrame to a CSV file
df_metadata_all.to_csv("GSE44861_metadata_all.csv", index=False)

# %%
print(list(df_metadata_all.columns))
# Out:
# ['title', 'geo_accession', 'status', 'submission_date', 'last_update_date', 'type', 'channel_count', 'source_name_ch1', 'organism_ch1', 'case_id', 'characteristics_ch1', 'characteristics_ch2', 'characteristics_ch3', 'characteristics_ch4', 'characteristics_ch5', 'treatment_protocol_ch1', 'growth_protocol_ch1', 'molecule_ch1', 'extract_protocol_ch1', 'label_ch1', 'label_protocol_ch1', 'taxid_ch1', 'hyb_protocol', 'scan_protocol', 'description', 'data_processing', 'platform_id', 'contact_name', 'contact_email', 'contact_department', 'contact_institute', 'contact_address', 'contact_city', 'contact_state', 'contact_zip/postal_code', 'contact_country', 'supplementary_file', 'data_row_count']

# %%
df_metadata_all.tail()
# Out:
#         title geo_accession                   status submission_date  \
# 106  "15430T"  "GSM1093015"  "Public on Feb 19 2014"   "Mar 05 2013"
# 107  "15527N"  "GSM1093016"  "Public on Feb 19 2014"   "Mar 05 2013"
# 108  "15527T"  "GSM1093017"  "Public on Feb 19 2014"   "Mar 05 2013"
# 109  "15556N"  "GSM1093018"  "Public on Feb 19 2014"   "Mar 05 2013"
# 110  "15556T"  "GSM1093019"  "Public on Feb 19 2014"   "Mar 05 2013"
#
#     last_update_date   type channel_count  \
# 106    "Jun 02 2014"  "RNA"           "1"
# 107    "Jun 02 2014"  "RNA"           "1"
# 108    "Jun 02 2014"  "RNA"           "1"
# 109    "Jun 02 2014"  "RNA"           "1"
# 110    "Jun 02 2014"  "RNA"           "1"
#
#                                    source_name_ch1    organism_ch1  \
# 106  "Colon tissue from patient with colon cancer"  "Homo sapiens"
# 107  "Colon tissue from patient with colon cancer"  "Homo sapiens"
# 108  "Colon tissue from patient with colon cancer"  "Homo sapiens"
# ...

# %%
for col in df_metadata_all.columns:
    print(f"Column: {col}")
    print(df_metadata_all[col].head())  # Show first few values of each column
    print("-" * 50)
# Out:
# Column: title
# 0    "10167 N"
# 1    "10167 T"
# 2    "10212 N"
# 3    "10212 T"
# 4    "10515 N"
# Name: title, dtype: object
# --------------------------------------------------
# Column: geo_accession
# 0    "GSM1092909"
# 1    "GSM1092910"
# 2    "GSM1092911"
# 3    "GSM1092912"
# 4    "GSM1092913"
# Name: geo_accession, dtype: object
# --------------------------------------------------
# Column: status
# 0    "Public on Feb 19 2014"
# 1    "Public on Feb 19 2014"
# 2    "Public on Feb 19 2014"
# 3    "Public on Feb 19 2014"
# 4    "Public on Feb 19 2014"
# Name: status, dtype: object
# --------------------------------------------------
# Column: submission_date
# 0    "Mar 05 2013"
# 1    "Mar 05 2013"
# 2    "Mar 05 2013"
# 3    "Mar 05 2013"
# 4    "Mar 05 2013"
# Name: submission_date, dtype: object
# --------------------------------------------------
# Column: last_update_date
# 0    "Jun 02 2014"
# 1    "Jun 02 2014"
# 2    "Jun 02 2014"
# 3    "Jun 02 2014"
# ...

# %%
file_path = "GSE44861_series_matrix.txt"
data = pd.read_csv(file_path, sep="\t", comment="!", header=0)
print(data.head())
# Out:
#       ID_REF  GSM1092909  GSM1092910  GSM1092911  GSM1092912  GSM1092913  \
# 0  1007_s_at    11.76220    10.57850    10.88280    11.23300    10.05570
# 1    1053_at     6.29542     6.77451     6.30281     8.18885     6.27496
# 2     117_at     5.55660     5.58586     5.61578     6.09570     5.99864
# 3     121_at     7.81090     7.66729     8.43118     7.81232     7.52846
# 4  1255_g_at     5.24249     5.21854     5.33201     5.30253     5.30274
#
#    GSM1092914  GSM1092915  GSM1092916  GSM1092917  ...  GSM1093010  \
# 0     8.71981    10.10320    10.33610    10.40220  ...    10.86280
# 1     7.23963     6.32391     6.68181     5.83710  ...     6.43236
# 2     6.77403     5.62292     5.62754     5.61482  ...     5.99220
# 3     7.62669     8.14157     8.25435     8.44242  ...     7.65229
# 4     5.19317     5.39920     5.37089     5.60335  ...     5.31678
#
#    GSM1093011  GSM1093012  GSM1093013  GSM1093014  GSM1093015  GSM1093016  \
# ...

# %%
data
# Out:
#                 ID_REF  GSM1092909  GSM1092910  GSM1092911  GSM1092912  \
# 0            1007_s_at    11.76220    10.57850    10.88280    11.23300
# 1              1053_at     6.29542     6.77451     6.30281     8.18885
# 2               117_at     5.55660     5.58586     5.61578     6.09570
# 3               121_at     7.81090     7.66729     8.43118     7.81232
# 4            1255_g_at     5.24249     5.21854     5.33201     5.30253
# ...                ...         ...         ...         ...         ...
# 22272   AFFX-ThrX-5_at     5.38740     5.37360     5.32175     5.46719
# 22273   AFFX-ThrX-M_at     5.50055     5.52497     5.59045     5.45065
# 22274  AFFX-TrpnX-3_at     5.01456     5.11313     5.14005     5.06556
# 22275  AFFX-TrpnX-5_at     5.04927     5.05536     5.19297     5.04587
# 22276  AFFX-TrpnX-M_at     5.05146     5.01421     5.28986     4.99616
#
#        GSM1092913  GSM1092914  GSM1092915  GSM1092916  GSM1092917  ...  \
# ...

# %%
data.to_csv("GSE44861_gene_expression.csv", index=False)
