# %%
import pandas as pd

# %%
#read all metadata
metadata_file = "GSE44861_metadata_all.csv" 
metadata = pd.read_csv(metadata_file)

# %%
metadata.describe()
# Out:
#             title geo_accession                   status submission_date  \
# count         111           111                      111             111
# unique        111           111                        1               1
# top     "10167 N"  "GSM1092909"  "Public on Feb 19 2014"   "Mar 05 2013"
# freq            1             1                      111             111
#
#        last_update_date   type channel_count  \
# count               111    111           111
# unique                1      1             1
# top       "Jun 02 2014"  "RNA"           "1"
# freq                111    111           111
#
#                                       source_name_ch1    organism_ch1  \
# count                                             111             111
# unique                                              1               1
# top     "Colon tissue from patient with colon cancer"  "Homo sapiens"
# freq                                              111             111
#
# ...

# %%
metadata.head()
# Out:
#        title geo_accession                   status submission_date  \
# 0  "10167 N"  "GSM1092909"  "Public on Feb 19 2014"   "Mar 05 2013"
# 1  "10167 T"  "GSM1092910"  "Public on Feb 19 2014"   "Mar 05 2013"
# 2  "10212 N"  "GSM1092911"  "Public on Feb 19 2014"   "Mar 05 2013"
# 3  "10212 T"  "GSM1092912"  "Public on Feb 19 2014"   "Mar 05 2013"
# 4  "10515 N"  "GSM1092913"  "Public on Feb 19 2014"   "Mar 05 2013"
#
#   last_update_date   type channel_count  \
# 0    "Jun 02 2014"  "RNA"           "1"
# 1    "Jun 02 2014"  "RNA"           "1"
# 2    "Jun 02 2014"  "RNA"           "1"
# 3    "Jun 02 2014"  "RNA"           "1"
# 4    "Jun 02 2014"  "RNA"           "1"
#
#                                  source_name_ch1    organism_ch1  \
# 0  "Colon tissue from patient with colon cancer"  "Homo sapiens"
# 1  "Colon tissue from patient with colon cancer"  "Homo sapiens"
# 2  "Colon tissue from patient with colon cancer"  "Homo sapiens"
# ...

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    111 non-null    object
#  1   geo_accession            111 non-null    object
#  2   status                   111 non-null    object
#  3   submission_date          111 non-null    object
#  4   last_update_date         111 non-null    object
#  5   type                     111 non-null    object
#  6   channel_count            111 non-null    object
#  7   source_name_ch1          111 non-null    object
#  8   organism_ch1             111 non-null    object
#  9   case_id                  111 non-null    object
#  10  characteristics_ch1      111 non-null    object
#  11  characteristics_ch2      111 non-null    object
#  12  characteristics_ch3      111 non-null    object
#  13  characteristics_ch4      111 non-null    object
# ...

# %%
metadata.shape
# Out:
# (111, 38)

# %%
metadata.columns
# Out:
# Index(['title', 'geo_accession', 'status', 'submission_date',
#        'last_update_date', 'type', 'channel_count', 'source_name_ch1',
#        'organism_ch1', 'case_id', 'characteristics_ch1', 'characteristics_ch2',
#        'characteristics_ch3', 'characteristics_ch4', 'characteristics_ch5',
#        'treatment_protocol_ch1', 'growth_protocol_ch1', 'molecule_ch1',
#        'extract_protocol_ch1', 'label_ch1', 'label_protocol_ch1', 'taxid_ch1',
#        'hyb_protocol', 'scan_protocol', 'description', 'data_processing',
#        'platform_id', 'contact_name', 'contact_email', 'contact_department',
#        'contact_institute', 'contact_address', 'contact_city', 'contact_state',
#        'contact_zip/postal_code', 'contact_country', 'supplementary_file',
#        'data_row_count'],
#       dtype='object')
