# %%
import pandas as pd
import numpy as np

# %%
# Load the filtered metadata file
metadata_path = "GSE44076_merged_data.csv"
metadata = pd.read_csv(metadata_path)

# replace '--' with NaN in the Stage column
metadata["stage"] = metadata["stage"].replace("--", np.nan)

# normalize stage values
metadata["stage"] = metadata["stage"].str.upper()

# %%
metadata.head()
# Out:
#   geo_accession sample_type individual_id stage location  gender  age  \
# 0    GSM1077598      Mucosa         A2119   NaN     Left    Male   62
# 1    GSM1077599      Mucosa         A2142   NaN     Left  Female   77
# 2    GSM1077600      Mucosa         B2104   NaN     Left  Female   78
# 3    GSM1077601      Mucosa         B2127   NaN    Right    Male   65
# 4    GSM1077602      Mucosa         B2150   NaN    Right  Female   52
#
#                   status  11715100_at  11715101_s_at  ...  AFFX-r2-TagO-3_at  \
# 0  Public on Mar 14 2014       3.6599         4.1524  ...             1.9475
# 1  Public on Mar 14 2014       2.5712         4.1879  ...             1.9056
# 2  Public on Mar 14 2014       3.3174         4.1040  ...             2.5070
# 3  Public on Mar 14 2014       3.1835         4.3635  ...             2.0228
# 4  Public on Mar 14 2014       2.9949         4.5227  ...             1.9309
#
#    AFFX-r2-TagO-5_at  AFFX-r2-TagQ-3_at  AFFX-r2-TagQ-5_at  AFFX-ThrX-3_at  \
# ...

# %%
metadata.tail()
# Out:
#     geo_accession sample_type individual_id stage location  gender  age  \
# 241    GSM1077839       Tumor         Y2099   IIA    Right    Male   72
# 242    GSM1077840       Tumor         Z2015   IIA    Right    Male   84
# 243    GSM1077841       Tumor         Z2038   IIA    Right  Female   65
# 244    GSM1077842       Tumor         Z2061   IIA     Left    Male   53
# 245    GSM1077843       Tumor         Z2084   IIA     Left    Male   81
#
#                     status  11715100_at  11715101_s_at  ...  \
# 241  Public on Mar 14 2014       2.7624         3.7898  ...
# 242  Public on Mar 14 2014       2.5775         3.7737  ...
# 243  Public on Mar 14 2014       3.1441         4.3357  ...
# 244  Public on Mar 14 2014       4.8256         5.4895  ...
# 245  Public on Mar 14 2014       3.3535         4.4803  ...
#
#      AFFX-r2-TagO-3_at  AFFX-r2-TagO-5_at  AFFX-r2-TagQ-3_at  \
# 241             1.8331             2.3223             2.3968
# ...

# %%
stage_mapping = {
    '0': 'Early',
    'I': 'Early',
    'IA': 'Early',
    'IB': 'Early',
    'IC': 'Early',
    'II': 'Intermediate',
    'IIA': 'Intermediate',
    'IIB': 'Intermediate',
    'IIC': 'Intermediate',
    'II': 'Advanced',
    'IIIA': 'Advanced',
    'IIIB': 'Advanced',
    'IIIC': 'Advanced',
    'IV': 'Advanced',
    'IVA': 'Advanced',
    'IVB': 'Advanced',
    'IVC': 'Advanced'
}
# map the 'stage' column to the broader categories
metadata['stage_category'] = metadata['stage'].map(stage_mapping)

# handle any unmapped or missing values
metadata['stage_category'] = metadata['stage_category'].fillna('Unknown')

# Save the updated DataFrame to a new CSV file
#metadata.to_csv('processed_metadata_with_stage_categories.csv', index=False)

#print("Processed metadata saved as 'processed_metadata_with_stage_categories.csv'")

# %%
metadata.head()
# Out:
#   geo_accession sample_type individual_id stage location  gender  age  \
# 0    GSM1077598      Mucosa         A2119   NaN     Left    Male   62
# 1    GSM1077599      Mucosa         A2142   NaN     Left  Female   77
# 2    GSM1077600      Mucosa         B2104   NaN     Left  Female   78
# 3    GSM1077601      Mucosa         B2127   NaN    Right    Male   65
# 4    GSM1077602      Mucosa         B2150   NaN    Right  Female   52
#
#                   status  11715100_at  11715101_s_at  ...  AFFX-r2-TagO-5_at  \
# 0  Public on Mar 14 2014       3.6599         4.1524  ...             2.1732
# 1  Public on Mar 14 2014       2.5712         4.1879  ...             1.9503
# 2  Public on Mar 14 2014       3.3174         4.1040  ...             2.4232
# 3  Public on Mar 14 2014       3.1835         4.3635  ...             2.7202
# 4  Public on Mar 14 2014       2.9949         4.5227  ...             2.1284
#
#    AFFX-r2-TagQ-3_at  AFFX-r2-TagQ-5_at  AFFX-ThrX-3_at  AFFX-ThrX-5_at  \
# ...

# %%
metadata.tail()
# Out:
#     geo_accession sample_type individual_id stage location  gender  age  \
# 241    GSM1077839       Tumor         Y2099   IIA    Right    Male   72
# 242    GSM1077840       Tumor         Z2015   IIA    Right    Male   84
# 243    GSM1077841       Tumor         Z2038   IIA    Right  Female   65
# 244    GSM1077842       Tumor         Z2061   IIA     Left    Male   53
# 245    GSM1077843       Tumor         Z2084   IIA     Left    Male   81
#
#                     status  11715100_at  11715101_s_at  ...  \
# 241  Public on Mar 14 2014       2.7624         3.7898  ...
# 242  Public on Mar 14 2014       2.5775         3.7737  ...
# 243  Public on Mar 14 2014       3.1441         4.3357  ...
# 244  Public on Mar 14 2014       4.8256         5.4895  ...
# 245  Public on Mar 14 2014       3.3535         4.4803  ...
#
#      AFFX-r2-TagO-5_at  AFFX-r2-TagQ-3_at  AFFX-r2-TagQ-5_at  AFFX-ThrX-3_at  \
# 241             2.3223             2.3968             2.1180          6.9047
# ...

# %%
column_to_move = metadata.columns[49394]
columns = list(metadata.columns)
columns.remove(column_to_move)
columns.insert(4, column_to_move)

# Reorder the DataFrame
metadata = metadata[columns]

# %%
metadata.head()
# Out:
#   geo_accession sample_type individual_id stage stage_category location  \
# 0    GSM1077598      Mucosa         A2119   NaN        Unknown     Left
# 1    GSM1077599      Mucosa         A2142   NaN        Unknown     Left
# 2    GSM1077600      Mucosa         B2104   NaN        Unknown     Left
# 3    GSM1077601      Mucosa         B2127   NaN        Unknown    Right
# 4    GSM1077602      Mucosa         B2150   NaN        Unknown    Right
#
#    gender  age                 status  11715100_at  ...  AFFX-r2-TagO-3_at  \
# 0    Male   62  Public on Mar 14 2014       3.6599  ...             1.9475
# 1  Female   77  Public on Mar 14 2014       2.5712  ...             1.9056
# 2  Female   78  Public on Mar 14 2014       3.3174  ...             2.5070
# 3    Male   65  Public on Mar 14 2014       3.1835  ...             2.0228
# 4  Female   52  Public on Mar 14 2014       2.9949  ...             1.9309
#
#    AFFX-r2-TagO-5_at  AFFX-r2-TagQ-3_at  AFFX-r2-TagQ-5_at  AFFX-ThrX-3_at  \
# ...

# %%
# save the updated DataFrame to a new CSV file
metadata.to_csv('processed_metadata_with_stage_categories.csv', index=False)

print("Processed metadata saved as 'processed_metadata_with_stage_categories.csv'")
# Out:
# Processed metadata saved as 'processed_metadata_with_stage_categories.csv'
