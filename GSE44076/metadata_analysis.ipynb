# %%
import pandas as pd

# %%
#read all metadata
metadata_file = "GSE44076_metadata_all.csv" 
metadata = pd.read_csv(metadata_file)

# %%
metadata.describe()
# Out:
#                                             title geo_accession  \
# count                                         246           246
# unique                                        246           246
# top     "Mucosa sample from A2119 healthy donnor"  "GSM1077598"
# freq                                            1             1
#
#                          status submission_date last_update_date   type  \
# count                       246             246              246    246
# unique                        1               1                1      1
# top     "Public on Mar 14 2014"   "Feb 05 2013"    "Aug 31 2023"  "RNA"
# freq                        246             246              246    246
#
#        channel_count                      source_name_ch1    organism_ch1  \
# count            246                                  246             246
# unique             1                                    3               1
# ...

# %%
metadata.head()
# Out:
#                                        title geo_accession  \
# 0  "Mucosa sample from A2119 healthy donnor"  "GSM1077598"
# 1  "Mucosa sample from A2142 healthy donnor"  "GSM1077599"
# 2  "Mucosa sample from B2104 healthy donnor"  "GSM1077600"
# 3  "Mucosa sample from B2127 healthy donnor"  "GSM1077601"
# 4  "Mucosa sample from B2150 healthy donnor"  "GSM1077602"
#
#                     status submission_date last_update_date   type  \
# 0  "Public on Mar 14 2014"   "Feb 05 2013"    "Aug 31 2023"  "RNA"
# 1  "Public on Mar 14 2014"   "Feb 05 2013"    "Aug 31 2023"  "RNA"
# 2  "Public on Mar 14 2014"   "Feb 05 2013"    "Aug 31 2023"  "RNA"
# 3  "Public on Mar 14 2014"   "Feb 05 2013"    "Aug 31 2023"  "RNA"
# 4  "Public on Mar 14 2014"   "Feb 05 2013"    "Aug 31 2023"  "RNA"
#
#   channel_count               source_name_ch1    organism_ch1  \
# 0           "1"  "Healthy colon mucosa cells"  "Homo sapiens"
# 1           "1"  "Healthy colon mucosa cells"  "Homo sapiens"
# ...

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   title                    246 non-null    object
#  1   geo_accession            246 non-null    object
#  2   status                   246 non-null    object
#  3   submission_date          246 non-null    object
#  4   last_update_date         246 non-null    object
#  5   type                     246 non-null    object
#  6   channel_count            246 non-null    object
#  7   source_name_ch1          246 non-null    object
#  8   organism_ch1             246 non-null    object
#  9   sample_type              246 non-null    object
#  10  individual_id            246 non-null    object
#  11  stage                    246 non-null    object
#  12  location                 246 non-null    object
#  13  gender                   246 non-null    object
# ...

# %%
metadata.shape
# Out:
# (246, 35)

# %%
metadata.columns
# Out:
# Index(['title', 'geo_accession', 'status', 'submission_date',
#        'last_update_date', 'type', 'channel_count', 'source_name_ch1',
#        'organism_ch1', 'sample_type', 'individual_id', 'stage', 'location',
#        'gender', 'age', 'molecule_ch1', 'extract_protocol_ch1', 'label_ch1',
#        'label_protocol_ch1', 'taxid_ch1', 'hyb_protocol', 'scan_protocol',
#        'data_processing', 'platform_id', 'contact_name', 'contact_email',
#        'contact_department', 'contact_institute', 'contact_address',
#        'contact_city', 'contact_state', 'contact_zip/postal_code',
#        'contact_country', 'supplementary_file', 'data_row_count'],
#       dtype='object')
